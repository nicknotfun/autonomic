# %%
import asyncio

from amp.system import System

HOSTS = ("10.1.0.200", "10.1.0.201")
VOLUME = 0.5

# %%
system = System(HOSTS, trace=True, read_only=False)

try:
    await asyncio.wait_for(system.discover(target_devices=2), timeout=10)
except asyncio.TimeoutError:
    print("Discovery timed out")

system.dump()
await system.state.save_to_file("state.json")
# Out:
# Connection error: inet_pton() argument 2 must be str, not tuple
# Traceback (most recent call last):
#   File "/home/nick/code/autonomic/amp/transport.py", line 164, in _loop
#     reader, writer = await asyncio.open_connection(self.host, self.port)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.14/asyncio/streams.py", line 48, in open_connection
#     transport, _ = await loop.create_connection(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         lambda: protocol, host, port, **kwds)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.14/asyncio/base_events.py", line 1119, in create_connection
#     infos = await self._ensure_resolved(
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         (host, port), family=family,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         type=socket.SOCK_STREAM, proto=proto, flags=flags, loop=self)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.14/asyncio/base_events.py", line 1511, in _ensure_resolved
#     info = _ipaddr_info(host, port, family, type, proto, *address[2:])
#   File "/usr/lib/python3.14/asyncio/base_events.py", line 146, in _ipaddr_info
#     socket.inet_pton(af, host)
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^
# TypeError: inet_pton() argument 2 must be str, not tuple
# Connection error: inet_pton() argument 2 must be str, not tuple
# Traceback (most recent call last):
#   File "/home/nick/code/autonomic/amp/transport.py", line 164, in _loop
#     reader, writer = await asyncio.open_connection(self.host, self.port)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.14/asyncio/streams.py", line 48, in open_connection
#     transport, _ = await loop.create_connection(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         lambda: protocol, host, port, **kwds)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.14/asyncio/base_events.py", line 1119, in create_connection
#     infos = await self._ensure_resolved(
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         (host, port), family=family,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         type=socket.SOCK_STREAM, proto=proto, flags=flags, loop=self)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.14/asyncio/base_events.py", line 1511, in _ensure_resolved
#     info = _ipaddr_info(host, port, family, type, proto, *address[2:])
#   File "/usr/lib/python3.14/asyncio/base_events.py", line 146, in _ipaddr_info
#     socket.inet_pton(af, host)
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^
# TypeError: inet_pton() argument 2 must be str, not tuple
# Discovery timed out
# Devices (0):
# Inputs (0):
# Outputs (0):
# Remote Inputs (0):
# Connection error: inet_pton() argument 2 must be str, not tuple
# Traceback (most recent call last):
#   File "/home/nick/code/autonomic/amp/transport.py", line 164, in _loop
#     reader, writer = await asyncio.open_connection(self.host, self.port)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.14/asyncio/streams.py", line 48, in open_connection
#     transport, _ = await loop.create_connection(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         lambda: protocol, host, port, **kwds)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.14/asyncio/base_events.py", line 1119, in create_connection
#     infos = await self._ensure_resolved(
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         (host, port), family=family,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         type=socket.SOCK_STREAM, proto=proto, flags=flags, loop=self)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.14/asyncio/base_events.py", line 1511, in _ensure_resolved
#     info = _ipaddr_info(host, port, family, type, proto, *address[2:])
#   File "/usr/lib/python3.14/asyncio/base_events.py", line 146, in _ipaddr_info
#     socket.inet_pton(af, host)
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^
# TypeError: inet_pton() argument 2 must be str, not tuple
# Connection error: inet_pton() argument 2 must be str, not tuple
# Traceback (most recent call last):
#   File "/home/nick/code/autonomic/amp/transport.py", line 164, in _loop
#     reader, writer = await asyncio.open_connection(self.host, self.port)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.14/asyncio/streams.py", line 48, in open_connection
#     transport, _ = await loop.create_connection(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         lambda: protocol, host, port, **kwds)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.14/asyncio/base_events.py", line 1119, in create_connection
#     infos = await self._ensure_resolved(
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         (host, port), family=family,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         type=socket.SOCK_STREAM, proto=proto, flags=flags, loop=self)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.14/asyncio/base_events.py", line 1511, in _ensure_resolved
#     info = _ipaddr_info(host, port, family, type, proto, *address[2:])
#   File "/usr/lib/python3.14/asyncio/base_events.py", line 146, in _ipaddr_info
#     socket.inet_pton(af, host)
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^
# TypeError: inet_pton() argument 2 must be str, not tuple
# Connection error: inet_pton() argument 2 must be str, not tuple
# Traceback (most recent call last):
#   File "/home/nick/code/autonomic/amp/transport.py", line 164, in _loop
#     reader, writer = await asyncio.open_connection(self.host, self.port)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.14/asyncio/streams.py", line 48, in open_connection
#     transport, _ = await loop.create_connection(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         lambda: protocol, host, port, **kwds)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.14/asyncio/base_events.py", line 1119, in create_connection
#     infos = await self._ensure_resolved(
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         (host, port), family=family,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         type=socket.SOCK_STREAM, proto=proto, flags=flags, loop=self)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.14/asyncio/base_events.py", line 1511, in _ensure_resolved
#     info = _ipaddr_info(host, port, family, type, proto, *address[2:])
#   File "/usr/lib/python3.14/asyncio/base_events.py", line 146, in _ipaddr_info
#     socket.inet_pton(af, host)
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^
# TypeError: inet_pton() argument 2 must be str, not tuple
# Connection error: inet_pton() argument 2 must be str, not tuple
# Traceback (most recent call last):
#   File "/home/nick/code/autonomic/amp/transport.py", line 164, in _loop
#     reader, writer = await asyncio.open_connection(self.host, self.port)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.14/asyncio/streams.py", line 48, in open_connection
#     transport, _ = await loop.create_connection(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         lambda: protocol, host, port, **kwds)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.14/asyncio/base_events.py", line 1119, in create_connection
#     infos = await self._ensure_resolved(
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         (host, port), family=family,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         type=socket.SOCK_STREAM, proto=proto, flags=flags, loop=self)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.14/asyncio/base_events.py", line 1511, in _ensure_resolved
#     info = _ipaddr_info(host, port, family, type, proto, *address[2:])
#   File "/usr/lib/python3.14/asyncio/base_events.py", line 146, in _ipaddr_info
#     socket.inet_pton(af, host)
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^
# TypeError: inet_pton() argument 2 must be str, not tuple

# %%
all_outputs = system.all_outputs()
w1 = system.input_by_name("W1")

print(f"W1 selector: 0x{w1.selector:02X}")

# %%
# Enable everything.
all_outputs.enable()

# %%
# Set all outputs to the same volume.
all_outputs.set_volume(VOLUME)

# %%
# Set all outputs to the input named W1.
all_outputs.set_input(w1)

# %%
# Mute everything.
all_outputs.mute()

# %%
system.refresh_outputs()
await asyncio.sleep(2)
system.dump()
system.shutdown()
