# %%
import asyncio

from amp.system import System

HOSTS = ("10.1.0.200", "10.1.0.201")
VOLUME = 0.5

# %%
system = System(HOSTS, trace=True, read_only=False)

try:
    await asyncio.wait_for(system.discover(target_devices=2), timeout=10)
except asyncio.TimeoutError:
    print("Discovery timed out")

system.dump()
await system.state.save_to_file("state.json")
# Out:
# --> 58ff00: UndocumentedHostIdentityCommand(output=255)
# --> 2fff: RequestZoneAssignmentsCommand(output=255, device_id=None)
# --> 14ff06: RequestDeviceInformationCommand(output=255, options=6)
# --> 58ff00: UndocumentedHostIdentityCommand(output=255)
# --> 2fff: RequestZoneAssignmentsCommand(output=255, device_id=None)
# --> 14ff06: RequestDeviceInformationCommand(output=255, options=6)
# <-- AFFF00D40102030405060708: RequestZoneAssignmentsCommandResponse(device_id=00D4, output=255, zones=(1, 2, 3, 4, 5, 6, 7, 8))
# <-- 94FF0006B000D40102030405060708: RequestDeviceInformationCommandResponse(device_id=00D4, firmware=6, model_id=B0, zones=(1, 2, 3, 4, 5, 6, 7, 8))
# --> 39ff00d4: RequestExtendedDeviceInformationCommand(output=255, device_id=00D4)
# --> 39ff00d4: RequestExtendedDeviceInformationCommand(output=255, device_id=00D4)
# --> 14ff06: RequestDeviceInformationCommand(output=255, options=6)
# --> 14ff06: RequestDeviceInformationCommand(output=255, options=6)
# --> 58ff00: UndocumentedHostIdentityCommand(output=255)
# --> 58ff00: UndocumentedHostIdentityCommand(output=255)
# --> 3aff00d485: NetworkSettingsDeviceGuidRequestCommand(device_id=00D4)
# --> 2fff: RequestZoneAssignmentsCommand(output=255, device_id=None)
# --> 2fff: RequestZoneAssignmentsCommand(output=255, device_id=None)
# <-- B9FF000000D40603001D230A0100C8ACE14F0055B41907150202: RequestExtendedDeviceInformationCommandResponse(device_id=00D4, prefix=0000, model_info=0603001D230A0100C8, mac=ACE14F0055B4, detail=1907150202)
# --> 14ff06: RequestDeviceInformationCommand(output=255, options=6)
# --> 14ff06: RequestDeviceInformationCommand(output=255, options=6)
# --> 58ff00: UndocumentedHostIdentityCommand(output=255)
# --> 58ff00: UndocumentedHostIdentityCommand(output=255)
# --> 3aff00d485: NetworkSettingsDeviceGuidRequestCommand(device_id=00D4)
# --> 2fff: RequestZoneAssignmentsCommand(output=255, device_id=None)
# --> 2fff: RequestZoneAssignmentsCommand(output=255, device_id=None)
# <-- 94FF0006B000D40102030405060708: RequestDeviceInformationCommandResponse(device_id=00D4, firmware=6, model_id=B0, zones=(1, 2, 3, 4, 5, 6, 7, 8))
# <-- 3AFF00D40500194E67A9F8BEF6A4653D0FBEE12977: NetworkSettingsDeviceGuidCommand(device_id=00D4, guid=UUID('674e1900-f8a9-f6be-a465-3d0fbee12977'))
# <-- AFFF00D40102030405060708: RequestZoneAssignmentsCommandResponse(device_id=00D4, output=255, zones=(1, 2, 3, 4, 5, 6, 7, 8))
# --> 58ff00: UndocumentedHostIdentityCommand(output=255)
# --> 58ff00: UndocumentedHostIdentityCommand(output=255)
# --> 2fff: RequestZoneAssignmentsCommand(output=255, device_id=None)
# --> 2fff: RequestZoneAssignmentsCommand(output=255, device_id=None)
# --> 14ff06: RequestDeviceInformationCommand(output=255, options=6)
# --> 14ff06: RequestDeviceInformationCommand(output=255, options=6)
# <-- 94FF0006B000D40102030405060708: RequestDeviceInformationCommandResponse(device_id=00D4, firmware=6, model_id=B0, zones=(1, 2, 3, 4, 5, 6, 7, 8))
# <-- 3AFF00D40500194E67A9F8BEF6A4653D0FBEE12977: NetworkSettingsDeviceGuidCommand(device_id=00D4, guid=UUID('674e1900-f8a9-f6be-a465-3d0fbee12977'))
# <-- AFFF00D40102030405060708: RequestZoneAssignmentsCommandResponse(device_id=00D4, output=255, zones=(1, 2, 3, 4, 5, 6, 7, 8))
# <-- 58FF00: UndocumentedHostIdentityCommand(output=255)
# <-- 58FF00: UndocumentedHostIdentityCommand(output=255)
# <-- AFFF00D40102030405060708: RequestZoneAssignmentsCommandResponse(device_id=00D4, output=255, zones=(1, 2, 3, 4, 5, 6, 7, 8))
# <-- 94FF0006B000D40102030405060708: RequestDeviceInformationCommandResponse(device_id=00D4, firmware=6, model_id=B0, zones=(1, 2, 3, 4, 5, 6, 7, 8))
# <-- 94FF0008E96012090A0B0C0D0E0F10: RequestDeviceInformationCommandResponse(device_id=6012, firmware=8, model_id=E9, zones=(9, 10, 11, 12, 13, 14, 15, 16))
# --> 58ff00: UndocumentedHostIdentityCommand(output=255)
# --> 58ff00: UndocumentedHostIdentityCommand(output=255)
# --> 39ff6012: RequestExtendedDeviceInformationCommand(output=255, device_id=6012)
# --> 39ff6012: RequestExtendedDeviceInformationCommand(output=255, device_id=6012)
# --> 3aff601285: NetworkSettingsDeviceGuidRequestCommand(device_id=6012)
# --> 3aff601285: NetworkSettingsDeviceGuidRequestCommand(device_id=6012)
# --> 2fff: RequestZoneAssignmentsCommand(output=255, device_id=None)
# --> 2fff: RequestZoneAssignmentsCommand(output=255, device_id=None)
# <-- AFFF00D40102030405060708: RequestZoneAssignmentsCommandResponse(device_id=00D4, output=255, zones=(1, 2, 3, 4, 5, 6, 7, 8))
# <-- 14FF06: RequestDeviceInformationCommand(output=255, options=6)
# --> 39ff6012: RequestExtendedDeviceInformationCommand(output=255, device_id=6012)
# --> 39ff6012: RequestExtendedDeviceInformationCommand(output=255, device_id=6012)
# --> 3aff601285: NetworkSettingsDeviceGuidRequestCommand(device_id=6012)
# <-- 94FF0008E96012090A0B0C0D0E0F10: RequestDeviceInformationCommandResponse(device_id=6012, firmware=8, model_id=E9, zones=(9, 10, 11, 12, 13, 14, 15, 16))
# <-- 94FF0008E96012090A0B0C0D0E0F10: RequestDeviceInformationCommandResponse(device_id=6012, firmware=8, model_id=E9, zones=(9, 10, 11, 12, 13, 14, 15, 16))
# <-- 14FF06: RequestDeviceInformationCommand(output=255, options=6)
# <-- 58FF00: UndocumentedHostIdentityCommand(output=255)
# <-- 14FF06: RequestDeviceInformationCommand(output=255, options=6)
# <-- 58FF00: UndocumentedHostIdentityCommand(output=255)
# <-- 58FF00: UndocumentedHostIdentityCommand(output=255)
# <-- 14FF06: RequestDeviceInformationCommand(output=255, options=6)
# <-- 94FF0008E96012090A0B0C0D0E0F10: RequestDeviceInformationCommandResponse(device_id=6012, firmware=8, model_id=E9, zones=(9, 10, 11, 12, 13, 14, 15, 16))
# <-- 14FF06: RequestDeviceInformationCommand(output=255, options=6)
# <-- 58FF00: UndocumentedHostIdentityCommand(output=255)
# <-- 94FF0008E96012090A0B0C0D0E0F10: RequestDeviceInformationCommandResponse(device_id=6012, firmware=8, model_id=E9, zones=(9, 10, 11, 12, 13, 14, 15, 16))
# <-- B9FF4F0060120803001C1C0A0100C9ACE14F00601211040F00AF: RequestExtendedDeviceInformationCommandResponse(device_id=6012, prefix=4F00, model_info=0803001C1C0A0100C9, mac=ACE14F006012, detail=11040F00AF)
# --> 3aff601285: NetworkSettingsDeviceGuidRequestCommand(device_id=6012)
# <-- 94FF0008E96012090A0B0C0D0E0F10: RequestDeviceInformationCommandResponse(device_id=6012, firmware=8, model_id=E9, zones=(9, 10, 11, 12, 13, 14, 15, 16))
# <-- 3AFF6012058768126C88DF41BDABBD079C4E743694: NetworkSettingsDeviceGuidCommand(device_id=6012, guid=UUID('6c126887-df88-bd41-abbd-079c4e743694'))
# <-- 3AFF601285: NetworkSettingsDeviceGuidRequestCommand(device_id=6012)
# --> 2901: SourceNameOptionsRequestCommand(output=1)
# --> 2909: SourceNameOptionsRequestCommand(output=9)
# --> 2902: SourceNameOptionsRequestCommand(output=2)
# --> 290a: SourceNameOptionsRequestCommand(output=10)
# --> 2903: SourceNameOptionsRequestCommand(output=3)
# --> 290b: SourceNameOptionsRequestCommand(output=11)
# --> 2904: SourceNameOptionsRequestCommand(output=4)
# --> 290c: SourceNameOptionsRequestCommand(output=12)
# --> 2905: SourceNameOptionsRequestCommand(output=5)
# --> 290d: SourceNameOptionsRequestCommand(output=13)
# --> 2906: SourceNameOptionsRequestCommand(output=6)
# --> 290e: SourceNameOptionsRequestCommand(output=14)
# --> 2907: SourceNameOptionsRequestCommand(output=7)
# --> 290f: SourceNameOptionsRequestCommand(output=15)
# --> 2908: SourceNameOptionsRequestCommand(output=8)
# --> 2910: SourceNameOptionsRequestCommand(output=16)
# --> 01ff: StandbyPowerCommand(output=255, is_on=None)
# --> 01ff: StandbyPowerCommand(output=255, is_on=None)
# --> 02ff: MuteCommand(output=255, is_muted=None)
# --> 02ff: MuteCommand(output=255, is_muted=None)
# --> 03ff: SourceSelectionCommand(output=255, source=None, detail=())
# --> 03ff: SourceSelectionCommand(output=255, source=None, detail=())
# --> 04ff: VolumeCommand(output=255, volume=None, detail=())
# --> 04ff: VolumeCommand(output=255, volume=None, detail=())
# --> 0dff: MaximumVolumeCommand(output=255, max_volume=None, detail=())
# --> 0dff: MaximumVolumeCommand(output=255, max_volume=None, detail=())
# --> 38ff: ZoneNameRequestCommand(output=255)
# --> 38ff: ZoneNameRequestCommand(output=255)
# --> 4fff00: DistributedSourceDefinitionRequestCommand(output=255, slot_id=0)
# --> 4fff00: DistributedSourceDefinitionRequestCommand(output=255, slot_id=0)
# --> 4fff01: DistributedSourceDefinitionRequestCommand(output=255, slot_id=1)
# --> 4fff01: DistributedSourceDefinitionRequestCommand(output=255, slot_id=1)
# --> 4fff02: DistributedSourceDefinitionRequestCommand(output=255, slot_id=2)
# --> 4fff02: DistributedSourceDefinitionRequestCommand(output=255, slot_id=2)
# --> 4fff03: DistributedSourceDefinitionRequestCommand(output=255, slot_id=3)
# --> 4fff03: DistributedSourceDefinitionRequestCommand(output=255, slot_id=3)
# --> 4fff04: DistributedSourceDefinitionRequestCommand(output=255, slot_id=4)
# --> 4fff04: DistributedSourceDefinitionRequestCommand(output=255, slot_id=4)
# --> 4fff05: DistributedSourceDefinitionRequestCommand(output=255, slot_id=5)
# --> 4fff05: DistributedSourceDefinitionRequestCommand(output=255, slot_id=5)
# --> 4fff06: DistributedSourceDefinitionRequestCommand(output=255, slot_id=6)
# --> 4fff06: DistributedSourceDefinitionRequestCommand(output=255, slot_id=6)
# <-- 2901050000014131: SourceNameOptionsCommand(output=1, source_selector=5, options=000001, hidden_name=None, name='A1')
# <-- 2901060000014132: SourceNameOptionsCommand(output=1, source_selector=6, options=000001, hidden_name=None, name='A2')
# --> 4fff07: DistributedSourceDefinitionRequestCommand(output=255, slot_id=7)
# --> 4fff07: DistributedSourceDefinitionRequestCommand(output=255, slot_id=7)
# --> 4fff08: DistributedSourceDefinitionRequestCommand(output=255, slot_id=8)
# --> 4fff08: DistributedSourceDefinitionRequestCommand(output=255, slot_id=8)
# --> 4fff09: DistributedSourceDefinitionRequestCommand(output=255, slot_id=9)
# --> 4fff09: DistributedSourceDefinitionRequestCommand(output=255, slot_id=9)
# --> 4fff0a: DistributedSourceDefinitionRequestCommand(output=255, slot_id=10)
# --> 4fff0a: DistributedSourceDefinitionRequestCommand(output=255, slot_id=10)
# --> 4fff0b: DistributedSourceDefinitionRequestCommand(output=255, slot_id=11)
# --> 4fff0b: DistributedSourceDefinitionRequestCommand(output=255, slot_id=11)
# --> 4fff0c: DistributedSourceDefinitionRequestCommand(output=255, slot_id=12)
# --> 4fff0c: DistributedSourceDefinitionRequestCommand(output=255, slot_id=12)
# --> 4fff0d: DistributedSourceDefinitionRequestCommand(output=255, slot_id=13)
# --> 4fff0d: DistributedSourceDefinitionRequestCommand(output=255, slot_id=13)
# --> 4fff0e: DistributedSourceDefinitionRequestCommand(output=255, slot_id=14)
# --> 4fff0e: DistributedSourceDefinitionRequestCommand(output=255, slot_id=14)
# --> 4fff0f: DistributedSourceDefinitionRequestCommand(output=255, slot_id=15)
# --> 4fff0f: DistributedSourceDefinitionRequestCommand(output=255, slot_id=15)
# --> 4fff10: DistributedSourceDefinitionRequestCommand(output=255, slot_id=16)
# --> 4fff10: DistributedSourceDefinitionRequestCommand(output=255, slot_id=16)
# --> 4fff11: DistributedSourceDefinitionRequestCommand(output=255, slot_id=17)
# --> 4fff11: DistributedSourceDefinitionRequestCommand(output=255, slot_id=17)
# --> 4fff12: DistributedSourceDefinitionRequestCommand(output=255, slot_id=18)
# --> 4fff12: DistributedSourceDefinitionRequestCommand(output=255, slot_id=18)
# --> 4fff13: DistributedSourceDefinitionRequestCommand(output=255, slot_id=19)
# --> 4fff13: DistributedSourceDefinitionRequestCommand(output=255, slot_id=19)
# --> 4fff14: DistributedSourceDefinitionRequestCommand(output=255, slot_id=20)
# --> 4fff14: DistributedSourceDefinitionRequestCommand(output=255, slot_id=20)
# --> 4fff15: DistributedSourceDefinitionRequestCommand(output=255, slot_id=21)
# --> 4fff15: DistributedSourceDefinitionRequestCommand(output=255, slot_id=21)
# --> 4fff16: DistributedSourceDefinitionRequestCommand(output=255, slot_id=22)
# --> 4fff16: DistributedSourceDefinitionRequestCommand(output=255, slot_id=22)
# --> 4fff17: DistributedSourceDefinitionRequestCommand(output=255, slot_id=23)
# --> 4fff17: DistributedSourceDefinitionRequestCommand(output=255, slot_id=23)
# --> 4fff18: DistributedSourceDefinitionRequestCommand(output=255, slot_id=24)
# --> 4fff18: DistributedSourceDefinitionRequestCommand(output=255, slot_id=24)
# --> 4fff19: DistributedSourceDefinitionRequestCommand(output=255, slot_id=25)
# --> 4fff19: DistributedSourceDefinitionRequestCommand(output=255, slot_id=25)
# --> 4fff1a: DistributedSourceDefinitionRequestCommand(output=255, slot_id=26)
# --> 4fff1a: DistributedSourceDefinitionRequestCommand(output=255, slot_id=26)
# --> 4fff1b: DistributedSourceDefinitionRequestCommand(output=255, slot_id=27)
# --> 4fff1b: DistributedSourceDefinitionRequestCommand(output=255, slot_id=27)
# --> 4fff1c: DistributedSourceDefinitionRequestCommand(output=255, slot_id=28)
# --> 4fff1c: DistributedSourceDefinitionRequestCommand(output=255, slot_id=28)
# --> 4fff1d: DistributedSourceDefinitionRequestCommand(output=255, slot_id=29)
# --> 4fff1d: DistributedSourceDefinitionRequestCommand(output=255, slot_id=29)
# --> 4fff1e: DistributedSourceDefinitionRequestCommand(output=255, slot_id=30)
# --> 4fff1e: DistributedSourceDefinitionRequestCommand(output=255, slot_id=30)
# --> 4fff1f: DistributedSourceDefinitionRequestCommand(output=255, slot_id=31)
# --> 4fff1f: DistributedSourceDefinitionRequestCommand(output=255, slot_id=31)
# <-- 2901070000014133: SourceNameOptionsCommand(output=1, source_selector=7, options=000001, hidden_name=None, name='A3')
# <-- 2901030000014134: SourceNameOptionsCommand(output=1, source_selector=3, options=000001, hidden_name=None, name='A4')
# <-- 2902050000014131: SourceNameOptionsCommand(output=2, source_selector=5, options=000001, hidden_name=None, name='A1')
# <-- 2903050000014131: SourceNameOptionsCommand(output=3, source_selector=5, options=000001, hidden_name=None, name='A1')
# <-- 2904050000014131: SourceNameOptionsCommand(output=4, source_selector=5, options=000001, hidden_name=None, name='A1')
# <-- 2905050000014131: SourceNameOptionsCommand(output=5, source_selector=5, options=000001, hidden_name=None, name='A1')
# <-- 2906050000014131: SourceNameOptionsCommand(output=6, source_selector=5, options=000001, hidden_name=None, name='A1')
# <-- 2907050000014131: SourceNameOptionsCommand(output=7, source_selector=5, options=000001, hidden_name=None, name='A1')
# <-- 2908050000014131: SourceNameOptionsCommand(output=8, source_selector=5, options=000001, hidden_name=None, name='A1')
# <-- 010100: StandbyPowerCommand(output=1, is_on=Off)
# <-- 010200: StandbyPowerCommand(output=2, is_on=Off)
# <-- 010300: StandbyPowerCommand(output=3, is_on=Off)
# <-- 010400: StandbyPowerCommand(output=4, is_on=Off)
# <-- 010500: StandbyPowerCommand(output=5, is_on=Off)
# <-- 010600: StandbyPowerCommand(output=6, is_on=Off)
# <-- 010700: StandbyPowerCommand(output=7, is_on=Off)
# <-- 010800: StandbyPowerCommand(output=8, is_on=Off)
# <-- 020101: MuteCommand(output=1, is_muted=Off)
# <-- 020201: MuteCommand(output=2, is_muted=Off)
# <-- 020301: MuteCommand(output=3, is_muted=Off)
# <-- 020401: MuteCommand(output=4, is_muted=Off)
# <-- 020501: MuteCommand(output=5, is_muted=Off)
# <-- 020601: MuteCommand(output=6, is_muted=Off)
# <-- 020701: MuteCommand(output=7, is_muted=Off)
# <-- 020801: MuteCommand(output=8, is_muted=Off)
# <-- 290100000001434F415831: SourceNameOptionsCommand(output=1, source_selector=0, options=000001, hidden_name=None, name='COAX1')
# <-- 2902060000014132: SourceNameOptionsCommand(output=2, source_selector=6, options=000001, hidden_name=None, name='A2')
# <-- 2903060000014132: SourceNameOptionsCommand(output=3, source_selector=6, options=000001, hidden_name=None, name='A2')
# <-- 2904060000014132: SourceNameOptionsCommand(output=4, source_selector=6, options=000001, hidden_name=None, name='A2')
# <-- 2905060000014132: SourceNameOptionsCommand(output=5, source_selector=6, options=000001, hidden_name=None, name='A2')
# <-- 2906060000014132: SourceNameOptionsCommand(output=6, source_selector=6, options=000001, hidden_name=None, name='A2')
# <-- 2907060000014132: SourceNameOptionsCommand(output=7, source_selector=6, options=000001, hidden_name=None, name='A2')
# <-- 2908060000014132: SourceNameOptionsCommand(output=8, source_selector=6, options=000001, hidden_name=None, name='A2')
# <-- 290101000001434F415832: SourceNameOptionsCommand(output=1, source_selector=1, options=000001, hidden_name=None, name='COAX2')
# <-- 2902070000014133: SourceNameOptionsCommand(output=2, source_selector=7, options=000001, hidden_name=None, name='A3')
# <-- 2903070000014133: SourceNameOptionsCommand(output=3, source_selector=7, options=000001, hidden_name=None, name='A3')
# <-- 2904070000014133: SourceNameOptionsCommand(output=4, source_selector=7, options=000001, hidden_name=None, name='A3')
# <-- 030126: SourceSelectionCommand(output=1, source=38, detail=())
# <-- 030227: SourceSelectionCommand(output=2, source=39, detail=())
# <-- 030321: SourceSelectionCommand(output=3, source=33, detail=())
# <-- 030421: SourceSelectionCommand(output=4, source=33, detail=())
# <-- 030506: SourceSelectionCommand(output=5, source=6, detail=())
# <-- 030624: SourceSelectionCommand(output=6, source=36, detail=())
# <-- 030706: SourceSelectionCommand(output=7, source=6, detail=())
# <-- 030806: SourceSelectionCommand(output=8, source=6, detail=())
# <-- 2905070000014133: SourceNameOptionsCommand(output=5, source_selector=7, options=000001, hidden_name=None, name='A3')
# <-- 2906070000014133: SourceNameOptionsCommand(output=6, source_selector=7, options=000001, hidden_name=None, name='A3')
# <-- 2907070000014133: SourceNameOptionsCommand(output=7, source_selector=7, options=000001, hidden_name=None, name='A3')
# <-- 2908070000014133: SourceNameOptionsCommand(output=8, source_selector=7, options=000001, hidden_name=None, name='A3')
# <-- 2901020000015731: SourceNameOptionsCommand(output=1, source_selector=2, options=000001, hidden_name=None, name='W1')
# <-- 2902030000014134: SourceNameOptionsCommand(output=2, source_selector=3, options=000001, hidden_name=None, name='A4')
# <-- 2903030000014134: SourceNameOptionsCommand(output=3, source_selector=3, options=000001, hidden_name=None, name='A4')
# <-- 2904030000014134: SourceNameOptionsCommand(output=4, source_selector=3, options=000001, hidden_name=None, name='A4')
# <-- 2905030000014134: SourceNameOptionsCommand(output=5, source_selector=3, options=000001, hidden_name=None, name='A4')
# <-- 2906030000014134: SourceNameOptionsCommand(output=6, source_selector=3, options=000001, hidden_name=None, name='A4')
# <-- 2907030000014134: SourceNameOptionsCommand(output=7, source_selector=3, options=000001, hidden_name=None, name='A4')
# <-- 2908030000014134: SourceNameOptionsCommand(output=8, source_selector=3, options=000001, hidden_name=None, name='A4')
# <-- 2901040000015732: SourceNameOptionsCommand(output=1, source_selector=4, options=000001, hidden_name=None, name='W2')
# <-- 290200000001434F415831: SourceNameOptionsCommand(output=2, source_selector=0, options=000001, hidden_name=None, name='COAX1')
# <-- 290300000001434F415831: SourceNameOptionsCommand(output=3, source_selector=0, options=000001, hidden_name=None, name='COAX1')
# <-- 290400000001434F415831: SourceNameOptionsCommand(output=4, source_selector=0, options=000001, hidden_name=None, name='COAX1')
# <-- 290500000001434F415831: SourceNameOptionsCommand(output=5, source_selector=0, options=000001, hidden_name=None, name='COAX1')
# <-- 290600000001434F415831: SourceNameOptionsCommand(output=6, source_selector=0, options=000001, hidden_name=None, name='COAX1')
# <-- 290700000001434F415831: SourceNameOptionsCommand(output=7, source_selector=0, options=000001, hidden_name=None, name='COAX1')
# <-- 290800000001434F415831: SourceNameOptionsCommand(output=8, source_selector=0, options=000001, hidden_name=None, name='COAX1')
# <-- 2901200000005731: SourceNameOptionsCommand(output=1, source_selector=32, options=000000, hidden_name=None, name='W1')
# <-- 290201000001434F415832: SourceNameOptionsCommand(output=2, source_selector=1, options=000001, hidden_name=None, name='COAX2')
# <-- 290301000001434F415832: SourceNameOptionsCommand(output=3, source_selector=1, options=000001, hidden_name=None, name='COAX2')
# <-- 290401000001434F415832: SourceNameOptionsCommand(output=4, source_selector=1, options=000001, hidden_name=None, name='COAX2')
# <-- 290501000001434F415832: SourceNameOptionsCommand(output=5, source_selector=1, options=000001, hidden_name=None, name='COAX2')
# <-- 290601000001434F415832: SourceNameOptionsCommand(output=6, source_selector=1, options=000001, hidden_name=None, name='COAX2')
# <-- 290701000001434F415832: SourceNameOptionsCommand(output=7, source_selector=1, options=000001, hidden_name=None, name='COAX2')
# <-- 290801000001434F415832: SourceNameOptionsCommand(output=8, source_selector=1, options=000001, hidden_name=None, name='COAX2')
# <-- 290121000000506C617965725F4140414345313446303036303132: SourceNameOptionsCommand(output=1, source_selector=33, options=000000, hidden_name=None, name='Player_A@ACE14F006012')
# <-- 2902020000015731: SourceNameOptionsCommand(output=2, source_selector=2, options=000001, hidden_name=None, name='W1')
# <-- 2903020000015731: SourceNameOptionsCommand(output=3, source_selector=2, options=000001, hidden_name=None, name='W1')
# <-- 2904020000015731: SourceNameOptionsCommand(output=4, source_selector=2, options=000001, hidden_name=None, name='W1')
# <-- 2905020000015731: SourceNameOptionsCommand(output=5, source_selector=2, options=000001, hidden_name=None, name='W1')
# <-- 2906020000015731: SourceNameOptionsCommand(output=6, source_selector=2, options=000001, hidden_name=None, name='W1')
# <-- 2907020000015731: SourceNameOptionsCommand(output=7, source_selector=2, options=000001, hidden_name=None, name='W1')
# <-- 2908020000015731: SourceNameOptionsCommand(output=8, source_selector=2, options=000001, hidden_name=None, name='W1')
# <-- 2901220000005732: SourceNameOptionsCommand(output=1, source_selector=34, options=000000, hidden_name=None, name='W2')
# <-- 2902040000015732: SourceNameOptionsCommand(output=2, source_selector=4, options=000001, hidden_name=None, name='W2')
# <-- 2903040000015732: SourceNameOptionsCommand(output=3, source_selector=4, options=000001, hidden_name=None, name='W2')
# <-- 2904040000015732: SourceNameOptionsCommand(output=4, source_selector=4, options=000001, hidden_name=None, name='W2')
# <-- 2905040000015732: SourceNameOptionsCommand(output=5, source_selector=4, options=000001, hidden_name=None, name='W2')
# <-- 2906040000015732: SourceNameOptionsCommand(output=6, source_selector=4, options=000001, hidden_name=None, name='W2')
# <-- 2907040000015732: SourceNameOptionsCommand(output=7, source_selector=4, options=000001, hidden_name=None, name='W2')
# <-- 2908040000015732: SourceNameOptionsCommand(output=8, source_selector=4, options=000001, hidden_name=None, name='W2')
# <-- 2901230000005733: SourceNameOptionsCommand(output=1, source_selector=35, options=000000, hidden_name=None, name='W3')
# <-- 2902200000005731: SourceNameOptionsCommand(output=2, source_selector=32, options=000000, hidden_name=None, name='W1')
# <-- 2903200000005731: SourceNameOptionsCommand(output=3, source_selector=32, options=000000, hidden_name=None, name='W1')
# <-- 2904200000005731: SourceNameOptionsCommand(output=4, source_selector=32, options=000000, hidden_name=None, name='W1')
# <-- 2905200000005731: SourceNameOptionsCommand(output=5, source_selector=32, options=000000, hidden_name=None, name='W1')
# <-- 2906200000005731: SourceNameOptionsCommand(output=6, source_selector=32, options=000000, hidden_name=None, name='W1')
# <-- 2907200000005731: SourceNameOptionsCommand(output=7, source_selector=32, options=000000, hidden_name=None, name='W1')
# <-- 2908200000005731: SourceNameOptionsCommand(output=8, source_selector=32, options=000000, hidden_name=None, name='W1')
# <-- 2901240000005734: SourceNameOptionsCommand(output=1, source_selector=36, options=000000, hidden_name=None, name='W4')
# <-- 290221000000506C617965725F4140414345313446303036303132: SourceNameOptionsCommand(output=2, source_selector=33, options=000000, hidden_name=None, name='Player_A@ACE14F006012')
# <-- 290321000000506C617965725F4140414345313446303036303132: SourceNameOptionsCommand(output=3, source_selector=33, options=000000, hidden_name=None, name='Player_A@ACE14F006012')
# <-- 290421000000506C617965725F4140414345313446303036303132: SourceNameOptionsCommand(output=4, source_selector=33, options=000000, hidden_name=None, name='Player_A@ACE14F006012')
# <-- 290521000000506C617965725F4140414345313446303036303132: SourceNameOptionsCommand(output=5, source_selector=33, options=000000, hidden_name=None, name='Player_A@ACE14F006012')
# <-- 290621000000506C617965725F4140414345313446303036303132: SourceNameOptionsCommand(output=6, source_selector=33, options=000000, hidden_name=None, name='Player_A@ACE14F006012')
# <-- 290721000000506C617965725F4140414345313446303036303132: SourceNameOptionsCommand(output=7, source_selector=33, options=000000, hidden_name=None, name='Player_A@ACE14F006012')
# <-- 290821000000506C617965725F4140414345313446303036303132: SourceNameOptionsCommand(output=8, source_selector=33, options=000000, hidden_name=None, name='Player_A@ACE14F006012')
# <-- 290125000000506173737468726F75676820496E: SourceNameOptionsCommand(output=1, source_selector=37, options=000000, hidden_name=None, name='Passthrough In')
# <-- 2902220000005732: SourceNameOptionsCommand(output=2, source_selector=34, options=000000, hidden_name=None, name='W2')
# <-- 2903220000005732: SourceNameOptionsCommand(output=3, source_selector=34, options=000000, hidden_name=None, name='W2')
# <-- 2904220000005732: SourceNameOptionsCommand(output=4, source_selector=34, options=000000, hidden_name=None, name='W2')
# <-- 2905220000005732: SourceNameOptionsCommand(output=5, source_selector=34, options=000000, hidden_name=None, name='W2')
# <-- 2906220000005732: SourceNameOptionsCommand(output=6, source_selector=34, options=000000, hidden_name=None, name='W2')
# <-- 2907220000005732: SourceNameOptionsCommand(output=7, source_selector=34, options=000000, hidden_name=None, name='W2')
# <-- 2908220000005732: SourceNameOptionsCommand(output=8, source_selector=34, options=000000, hidden_name=None, name='W2')
# <-- 290126000000506C617965725F4340414345313446303036303132: SourceNameOptionsCommand(output=1, source_selector=38, options=000000, hidden_name=None, name='Player_C@ACE14F006012')
# <-- 2902230000005733: SourceNameOptionsCommand(output=2, source_selector=35, options=000000, hidden_name=None, name='W3')
# <-- 2903230000005733: SourceNameOptionsCommand(output=3, source_selector=35, options=000000, hidden_name=None, name='W3')
# <-- 2904230000005733: SourceNameOptionsCommand(output=4, source_selector=35, options=000000, hidden_name=None, name='W3')
# <-- 2905230000005733: SourceNameOptionsCommand(output=5, source_selector=35, options=000000, hidden_name=None, name='W3')
# <-- 2906230000005733: SourceNameOptionsCommand(output=6, source_selector=35, options=000000, hidden_name=None, name='W3')
# <-- 2907230000005733: SourceNameOptionsCommand(output=7, source_selector=35, options=000000, hidden_name=None, name='W3')
# <-- 2908230000005733: SourceNameOptionsCommand(output=8, source_selector=35, options=000000, hidden_name=None, name='W3')
# <-- 290127000000506C617965725F4240414345313446303036303132: SourceNameOptionsCommand(output=1, source_selector=39, options=000000, hidden_name=None, name='Player_B@ACE14F006012')
# <-- 2902240000005734: SourceNameOptionsCommand(output=2, source_selector=36, options=000000, hidden_name=None, name='W4')
# <-- 2903240000005734: SourceNameOptionsCommand(output=3, source_selector=36, options=000000, hidden_name=None, name='W4')
# <-- 2904240000005734: SourceNameOptionsCommand(output=4, source_selector=36, options=000000, hidden_name=None, name='W4')
# <-- 2905240000005734: SourceNameOptionsCommand(output=5, source_selector=36, options=000000, hidden_name=None, name='W4')
# <-- 2906240000005734: SourceNameOptionsCommand(output=6, source_selector=36, options=000000, hidden_name=None, name='W4')
# <-- 2907240000005734: SourceNameOptionsCommand(output=7, source_selector=36, options=000000, hidden_name=None, name='W4')
# <-- 2908240000005734: SourceNameOptionsCommand(output=8, source_selector=36, options=000000, hidden_name=None, name='W4')
# <-- 290225000000506173737468726F75676820496E: SourceNameOptionsCommand(output=2, source_selector=37, options=000000, hidden_name=None, name='Passthrough In')
# <-- 290325000000506173737468726F75676820496E: SourceNameOptionsCommand(output=3, source_selector=37, options=000000, hidden_name=None, name='Passthrough In')
# <-- 290425000000506173737468726F75676820496E: SourceNameOptionsCommand(output=4, source_selector=37, options=000000, hidden_name=None, name='Passthrough In')
# <-- 290525000000506173737468726F75676820496E: SourceNameOptionsCommand(output=5, source_selector=37, options=000000, hidden_name=None, name='Passthrough In')
# <-- 290625000000506173737468726F75676820496E: SourceNameOptionsCommand(output=6, source_selector=37, options=000000, hidden_name=None, name='Passthrough In')
# <-- 290725000000506173737468726F75676820496E: SourceNameOptionsCommand(output=7, source_selector=37, options=000000, hidden_name=None, name='Passthrough In')
# <-- 290825000000506173737468726F75676820496E: SourceNameOptionsCommand(output=8, source_selector=37, options=000000, hidden_name=None, name='Passthrough In')
# <-- 290226000000506C617965725F4340414345313446303036303132: SourceNameOptionsCommand(output=2, source_selector=38, options=000000, hidden_name=None, name='Player_C@ACE14F006012')
# <-- 290326000000506C617965725F4340414345313446303036303132: SourceNameOptionsCommand(output=3, source_selector=38, options=000000, hidden_name=None, name='Player_C@ACE14F006012')
# <-- 290426000000506C617965725F4340414345313446303036303132: SourceNameOptionsCommand(output=4, source_selector=38, options=000000, hidden_name=None, name='Player_C@ACE14F006012')
# <-- 290526000000506C617965725F4340414345313446303036303132: SourceNameOptionsCommand(output=5, source_selector=38, options=000000, hidden_name=None, name='Player_C@ACE14F006012')
# <-- 290626000000506C617965725F4340414345313446303036303132: SourceNameOptionsCommand(output=6, source_selector=38, options=000000, hidden_name=None, name='Player_C@ACE14F006012')
# <-- 290726000000506C617965725F4340414345313446303036303132: SourceNameOptionsCommand(output=7, source_selector=38, options=000000, hidden_name=None, name='Player_C@ACE14F006012')
# <-- 290826000000506C617965725F4340414345313446303036303132: SourceNameOptionsCommand(output=8, source_selector=38, options=000000, hidden_name=None, name='Player_C@ACE14F006012')
# <-- 290227000000506C617965725F4240414345313446303036303132: SourceNameOptionsCommand(output=2, source_selector=39, options=000000, hidden_name=None, name='Player_B@ACE14F006012')
# <-- 290327000000506C617965725F4240414345313446303036303132: SourceNameOptionsCommand(output=3, source_selector=39, options=000000, hidden_name=None, name='Player_B@ACE14F006012')
# <-- 290427000000506C617965725F4240414345313446303036303132: SourceNameOptionsCommand(output=4, source_selector=39, options=000000, hidden_name=None, name='Player_B@ACE14F006012')
# <-- 290527000000506C617965725F4240414345313446303036303132: SourceNameOptionsCommand(output=5, source_selector=39, options=000000, hidden_name=None, name='Player_B@ACE14F006012')
# <-- 290627000000506C617965725F4240414345313446303036303132: SourceNameOptionsCommand(output=6, source_selector=39, options=000000, hidden_name=None, name='Player_B@ACE14F006012')
# <-- 290727000000506C617965725F4240414345313446303036303132: SourceNameOptionsCommand(output=7, source_selector=39, options=000000, hidden_name=None, name='Player_B@ACE14F006012')
# <-- 290827000000506C617965725F4240414345313446303036303132: SourceNameOptionsCommand(output=8, source_selector=39, options=000000, hidden_name=None, name='Player_B@ACE14F006012')
# <-- 04010000: VolumeCommand(output=1, volume=0.0, detail=(0,))
# <-- 04020000: VolumeCommand(output=2, volume=0.0, detail=(0,))
# <-- 04030000: VolumeCommand(output=3, volume=0.0, detail=(0,))
# <-- 04040000: VolumeCommand(output=4, volume=0.0, detail=(0,))
# <-- 04050000: VolumeCommand(output=5, volume=0.0, detail=(0,))
# <-- 04060000: VolumeCommand(output=6, volume=0.0, detail=(0,))
# <-- 04070000: VolumeCommand(output=7, volume=0.0, detail=(0,))
# <-- 04080000: VolumeCommand(output=8, volume=0.0, detail=(0,))
# <-- 0D01A0C8: MaximumVolumeCommand(output=1, max_volume=1.0, detail=(200,))
# <-- 0D02A0C8: MaximumVolumeCommand(output=2, max_volume=1.0, detail=(200,))
# <-- 0D03A0C8: MaximumVolumeCommand(output=3, max_volume=1.0, detail=(200,))
# <-- 0D04A0C8: MaximumVolumeCommand(output=4, max_volume=1.0, detail=(200,))
# <-- 0D05A0C8: MaximumVolumeCommand(output=5, max_volume=1.0, detail=(200,))
# <-- 0D06A0C8: MaximumVolumeCommand(output=6, max_volume=1.0, detail=(200,))
# <-- 0D07A0C8: MaximumVolumeCommand(output=7, max_volume=1.0, detail=(200,))
# <-- 0D08A0C8: MaximumVolumeCommand(output=8, max_volume=1.0, detail=(200,))
# <-- 1C014B69746368656E: ZoneNameCommand(output=1, name='Kitchen')
# <-- 1C0244696E696E67: ZoneNameCommand(output=2, name='Dining')
# <-- 1C034C6976696E67: ZoneNameCommand(output=3, name='Living')
# <-- 1C044D6173746572: ZoneNameCommand(output=4, name='Master')
# <-- 1C0542617468726F6F6D: ZoneNameCommand(output=5, name='Bathroom')
# <-- 1C06466F796572: ZoneNameCommand(output=6, name='Foyer')
# <-- 1C0753697474696E67: ZoneNameCommand(output=7, name='Sitting')
# <-- 1C08506173737468726F756768: ZoneNameCommand(output=8, name='Passthrough')
# <-- 4FFF0000194E67A9F8BEF6A4653D0FBEE12977065731: DistributedSourceDefinitionCommand(output=255, slot_id=0, backing_device_guid=UUID('674e1900-f8a9-f6be-a465-3d0fbee12977'), source_index=6, name='W1')
# <-- 4FFF016C126887DF88BD41ABBD079C4E74369400506C617965725F4140414345313446303036303132: DistributedSourceDefinitionCommand(output=255, slot_id=1, backing_device_guid=UUID('8768126c-88df-41bd-abbd-079c4e743694'), source_index=0, name='Player_A@ACE14F006012')
# <-- 4FFF0200194E67A9F8BEF6A4653D0FBEE12977075732: DistributedSourceDefinitionCommand(output=255, slot_id=2, backing_device_guid=UUID('674e1900-f8a9-f6be-a465-3d0fbee12977'), source_index=7, name='W2')
# <-- 4FFF038768126C88DF41BDABBD079C4E743694095733: DistributedSourceDefinitionCommand(output=255, slot_id=3, backing_device_guid=UUID('6c126887-df88-bd41-abbd-079c4e743694'), source_index=9, name='W3')
# <-- 4FFF048768126C88DF41BDABBD079C4E7436940A5734: DistributedSourceDefinitionCommand(output=255, slot_id=4, backing_device_guid=UUID('6c126887-df88-bd41-abbd-079c4e743694'), source_index=10, name='W4')
# <-- 4FFF058768126C88DF41BDABBD079C4E74369403506173737468726F75676820496E: DistributedSourceDefinitionCommand(output=255, slot_id=5, backing_device_guid=UUID('6c126887-df88-bd41-abbd-079c4e743694'), source_index=3, name='Passthrough In')
# <-- 4FFF066C126887DF88BD41ABBD079C4E74369402506C617965725F4340414345313446303036303132: DistributedSourceDefinitionCommand(output=255, slot_id=6, backing_device_guid=UUID('8768126c-88df-41bd-abbd-079c4e743694'), source_index=2, name='Player_C@ACE14F006012')
# <-- 94FF0008E96012090A0B0C0D0E0F10: RequestDeviceInformationCommandResponse(device_id=6012, firmware=8, model_id=E9, zones=(9, 10, 11, 12, 13, 14, 15, 16))
# <-- 4FFF076C126887DF88BD41ABBD079C4E74369401506C617965725F4240414345313446303036303132: DistributedSourceDefinitionCommand(output=255, slot_id=7, backing_device_guid=UUID('8768126c-88df-41bd-abbd-079c4e743694'), source_index=1, name='Player_B@ACE14F006012')
# <-- 4FFF0800: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=8)
# <-- 4FFF0900: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=9)
# <-- 4FFF0A00: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=10)
# <-- 4FFF0B00: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=11)
# <-- 4FFF0C00: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=12)
# <-- 4FFF0D00: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=13)
# <-- 4FFF0E00: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=14)
# <-- 4FFF0F00: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=15)
# <-- 4FFF1000: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=16)
# <-- 4FFF1100: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=17)
# <-- 4FFF1200: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=18)
# <-- 4FFF1300: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=19)
# <-- 4FFF1400: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=20)
# <-- 4FFF1500: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=21)
# <-- 4FFF1600: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=22)
# <-- 4FFF1700: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=23)
# <-- 4FFF1800: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=24)
# <-- 4FFF1900: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=25)
# <-- 4FFF1A00: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=26)
# <-- 4FFF1B00: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=27)
# <-- 4FFF1C00: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=28)
# <-- 4FFF1D00: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=29)
# <-- 4FFF1E00: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=30)
# <-- 4FFF1F00: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=31)
# <-- 94FF0008E96012090A0B0C0D0E0F10: RequestDeviceInformationCommandResponse(device_id=6012, firmware=8, model_id=E9, zones=(9, 10, 11, 12, 13, 14, 15, 16))
# <-- B9FF4F0060120803001C1C0A0100C9ACE14F00601211040F00AF: RequestExtendedDeviceInformationCommandResponse(device_id=6012, prefix=4F00, model_info=0803001C1C0A0100C9, mac=ACE14F006012, detail=11040F00AF)
# <-- 94FF0006B000D40102030405060708: RequestDeviceInformationCommandResponse(device_id=00D4, firmware=6, model_id=B0, zones=(1, 2, 3, 4, 5, 6, 7, 8))
# <-- B9FF000000D40603001D230A0100C8ACE14F0055B41907150002: RequestExtendedDeviceInformationCommandResponse(device_id=00D4, prefix=0000, model_info=0603001D230A0100C8, mac=ACE14F0055B4, detail=1907150002)
# <-- 010900: StandbyPowerCommand(output=9, is_on=Off)
# <-- 010A00: StandbyPowerCommand(output=10, is_on=Off)
# <-- 94FF0008E96012090A0B0C0D0E0F10: RequestDeviceInformationCommandResponse(device_id=6012, firmware=8, model_id=E9, zones=(9, 10, 11, 12, 13, 14, 15, 16))
# <-- 010B00: StandbyPowerCommand(output=11, is_on=Off)
# <-- 010C00: StandbyPowerCommand(output=12, is_on=Off)
# <-- 010D00: StandbyPowerCommand(output=13, is_on=Off)
# <-- 010E00: StandbyPowerCommand(output=14, is_on=Off)
# <-- 010F00: StandbyPowerCommand(output=15, is_on=Off)
# <-- 011000: StandbyPowerCommand(output=16, is_on=Off)
# <-- 01FF: StandbyPowerCommand(output=255, is_on=None)
# <-- 020900: MuteCommand(output=9, is_muted=On)
# <-- 020A00: MuteCommand(output=10, is_muted=On)
# <-- 020B00: MuteCommand(output=11, is_muted=On)
# <-- 020C00: MuteCommand(output=12, is_muted=On)
# <-- 020D00: MuteCommand(output=13, is_muted=On)
# <-- 020E00: MuteCommand(output=14, is_muted=On)
# <-- 020F00: MuteCommand(output=15, is_muted=On)
# <-- 021000: MuteCommand(output=16, is_muted=On)
# <-- 02FF: MuteCommand(output=255, is_muted=None)
# <-- 03090923: SourceSelectionCommand(output=9, source=9, detail=(35,))
# <-- 030A0923: SourceSelectionCommand(output=10, source=9, detail=(35,))
# <-- 030B0923: SourceSelectionCommand(output=11, source=9, detail=(35,))
# <-- 030C0923: SourceSelectionCommand(output=12, source=9, detail=(35,))
# <-- 030D0923: SourceSelectionCommand(output=13, source=9, detail=(35,))
# <-- 030E0923: SourceSelectionCommand(output=14, source=9, detail=(35,))
# <-- 030F0923: SourceSelectionCommand(output=15, source=9, detail=(35,))
# <-- 03100923: SourceSelectionCommand(output=16, source=9, detail=(35,))
# <-- 03FF: SourceSelectionCommand(output=255, source=None, detail=())
# <-- 040950: VolumeCommand(output=9, volume=0.5, detail=())
# <-- 040A50: VolumeCommand(output=10, volume=0.5, detail=())
# <-- 040B50: VolumeCommand(output=11, volume=0.5, detail=())
# <-- 040C50: VolumeCommand(output=12, volume=0.5, detail=())
# <-- 040D50: VolumeCommand(output=13, volume=0.5, detail=())
# <-- 040E50: VolumeCommand(output=14, volume=0.5, detail=())
# <-- 040F50: VolumeCommand(output=15, volume=0.5, detail=())
# <-- 041050: VolumeCommand(output=16, volume=0.5, detail=())
# <-- 04FF: VolumeCommand(output=255, volume=None, detail=())
# <-- 0D09A0000000: MaximumVolumeCommand(output=9, max_volume=1.0, detail=(0, 0, 0))
# <-- 0D0AA0000000: MaximumVolumeCommand(output=10, max_volume=1.0, detail=(0, 0, 0))
# <-- 0D0BA0000000: MaximumVolumeCommand(output=11, max_volume=1.0, detail=(0, 0, 0))
# <-- 0D0CA0000000: MaximumVolumeCommand(output=12, max_volume=1.0, detail=(0, 0, 0))
# <-- 0D0DA0000000: MaximumVolumeCommand(output=13, max_volume=1.0, detail=(0, 0, 0))
# <-- 0D0EA0000000: MaximumVolumeCommand(output=14, max_volume=1.0, detail=(0, 0, 0))
# <-- 0D0FA0000000: MaximumVolumeCommand(output=15, max_volume=1.0, detail=(0, 0, 0))
# <-- 0D10A0000000: MaximumVolumeCommand(output=16, max_volume=1.0, detail=(0, 0, 0))
# <-- 0DFF: MaximumVolumeCommand(output=255, max_volume=None, detail=())
# <-- 1C094772696C6C: ZoneNameCommand(output=9, name='Grill')
# <-- 1C0A506174696F2057657374: ZoneNameCommand(output=10, name='Patio West')
# <-- 1C0B506174696F2045617374: ZoneNameCommand(output=11, name='Patio East')
# <-- 1C0C506F6F6C: ZoneNameCommand(output=12, name='Pool')
# <-- 1C0D: ZoneNameCommand(output=13, name='')
# <-- 1C0E: ZoneNameCommand(output=14, name='')
# <-- 1C0F: ZoneNameCommand(output=15, name='')
# <-- 1C10: ZoneNameCommand(output=16, name='')
# <-- 38FF: ZoneNameRequestCommand(output=255)
# <-- 94FF0006B000D40102030405060708: RequestDeviceInformationCommandResponse(device_id=00D4, firmware=6, model_id=B0, zones=(1, 2, 3, 4, 5, 6, 7, 8))
# <-- B9FF4F0060120803001C1C0A0100C9ACE14F00601211040F00AF: RequestExtendedDeviceInformationCommandResponse(device_id=6012, prefix=4F00, model_info=0803001C1C0A0100C9, mac=ACE14F006012, detail=11040F00AF)
# <-- 14FF06: RequestDeviceInformationCommand(output=255, options=6)
# <-- 58FF00: UndocumentedHostIdentityCommand(output=255)
# <-- 3AFF6012058768126C88DF41BDABBD079C4E743694: NetworkSettingsDeviceGuidCommand(device_id=6012, guid=UUID('6c126887-df88-bd41-abbd-079c4e743694'))
# <-- 94FF0008E96012090A0B0C0D0E0F10: RequestDeviceInformationCommandResponse(device_id=6012, firmware=8, model_id=E9, zones=(9, 10, 11, 12, 13, 14, 15, 16))
# <-- B9FF4F0060120803001C1C0A0100C9ACE14F00601211040F00AF: RequestExtendedDeviceInformationCommandResponse(device_id=6012, prefix=4F00, model_info=0803001C1C0A0100C9, mac=ACE14F006012, detail=11040F00AF)
# <-- B9FF4F0060120803001C1C0A0100C9ACE14F00601211040F00AF: RequestExtendedDeviceInformationCommandResponse(device_id=6012, prefix=4F00, model_info=0803001C1C0A0100C9, mac=ACE14F006012, detail=11040F00AF)
# <-- 94FF0008E96012090A0B0C0D0E0F10: RequestDeviceInformationCommandResponse(device_id=6012, firmware=8, model_id=E9, zones=(9, 10, 11, 12, 13, 14, 15, 16))
# <-- 3AFF6012058768126C88DF41BDABBD079C4E743694: NetworkSettingsDeviceGuidCommand(device_id=6012, guid=UUID('6c126887-df88-bd41-abbd-079c4e743694'))
# <-- 14FF06: RequestDeviceInformationCommand(output=255, options=6)
# <-- 94FF0006B000D40102030405060708: RequestDeviceInformationCommandResponse(device_id=00D4, firmware=6, model_id=B0, zones=(1, 2, 3, 4, 5, 6, 7, 8))
# <-- 3AFF6012058768126C88DF41BDABBD079C4E743694: NetworkSettingsDeviceGuidCommand(device_id=6012, guid=UUID('6c126887-df88-bd41-abbd-079c4e743694'))
# <-- 29090500000115506C617965725F4140414345313446303036303132506C617965725F41: SourceNameOptionsCommand(output=9, source_selector=5, options=000001, hidden_name='Player_A@ACE14F006012', name='Player_A')
# <-- 58FF00: UndocumentedHostIdentityCommand(output=255)
# <-- 29090600000115506C617965725F4240414345313446303036303132506C617965725F42: SourceNameOptionsCommand(output=9, source_selector=6, options=000001, hidden_name='Player_B@ACE14F006012', name='Player_B')
# <-- 29090700000115506C617965725F4340414345313446303036303132506C617965725F43: SourceNameOptionsCommand(output=9, source_selector=7, options=000001, hidden_name='Player_C@ACE14F006012', name='Player_C')
# <-- 290903000001416E616C6F672031: SourceNameOptionsCommand(output=9, source_selector=3, options=000001, hidden_name=None, name='Analog 1')
# <-- 290900000001416E616C6F672032: SourceNameOptionsCommand(output=9, source_selector=0, options=000001, hidden_name=None, name='Analog 2')
# <-- 290901000001416E616C6F672033: SourceNameOptionsCommand(output=9, source_selector=1, options=000001, hidden_name=None, name='Analog 3')
# <-- 290902000001416E616C6F672034: SourceNameOptionsCommand(output=9, source_selector=2, options=000001, hidden_name=None, name='Analog 4')
# <-- 290904000001436F617869616C2031: SourceNameOptionsCommand(output=9, source_selector=4, options=000001, hidden_name=None, name='Coaxial 1')
# <-- 290908000001436F617869616C2032: SourceNameOptionsCommand(output=9, source_selector=8, options=000001, hidden_name=None, name='Coaxial 2')
# <-- 2909090000015733: SourceNameOptionsCommand(output=9, source_selector=9, options=000001, hidden_name=None, name='W3')
# <-- 29090A0000015734: SourceNameOptionsCommand(output=9, source_selector=10, options=000001, hidden_name=None, name='W4')
# <-- 29090B0000011643617374696E675F314041434531344630303630313243617374696E675F31: SourceNameOptionsCommand(output=9, source_selector=11, options=000001, hidden_name='Casting_1@ACE14F006012', name='Casting_1')
# <-- 29090C0000011643617374696E675F324041434531344630303630313243617374696E675F32: SourceNameOptionsCommand(output=9, source_selector=12, options=000001, hidden_name='Casting_2@ACE14F006012', name='Casting_2')
# <-- 29090D0000011643617374696E675F334041434531344630303630313243617374696E675F33: SourceNameOptionsCommand(output=9, source_selector=13, options=000001, hidden_name='Casting_3@ACE14F006012', name='Casting_3')
# <-- 29090E0000011643617374696E675F344041434531344630303630313243617374696E675F34: SourceNameOptionsCommand(output=9, source_selector=14, options=000001, hidden_name='Casting_4@ACE14F006012', name='Casting_4')
# <-- 29090F0000011643617374696E675F354041434531344630303630313243617374696E675F35: SourceNameOptionsCommand(output=9, source_selector=15, options=000001, hidden_name='Casting_5@ACE14F006012', name='Casting_5')
# <-- 2909500000011643617374696E675F364041434531344630303630313243617374696E675F36: SourceNameOptionsCommand(output=9, source_selector=80, options=000001, hidden_name='Casting_6@ACE14F006012', name='Casting_6')
# <-- 2909510000011643617374696E675F374041434531344630303630313243617374696E675F37: SourceNameOptionsCommand(output=9, source_selector=81, options=000001, hidden_name='Casting_7@ACE14F006012', name='Casting_7')
# <-- 2909520000011643617374696E675F384041434531344630303630313243617374696E675F38: SourceNameOptionsCommand(output=9, source_selector=82, options=000001, hidden_name='Casting_8@ACE14F006012', name='Casting_8')
# <-- 290A0500000115506C617965725F4140414345313446303036303132506C617965725F41: SourceNameOptionsCommand(output=10, source_selector=5, options=000001, hidden_name='Player_A@ACE14F006012', name='Player_A')
# <-- 290A0600000115506C617965725F4240414345313446303036303132506C617965725F42: SourceNameOptionsCommand(output=10, source_selector=6, options=000001, hidden_name='Player_B@ACE14F006012', name='Player_B')
# <-- 290A0700000115506C617965725F4340414345313446303036303132506C617965725F43: SourceNameOptionsCommand(output=10, source_selector=7, options=000001, hidden_name='Player_C@ACE14F006012', name='Player_C')
# <-- 290A03000001416E616C6F672031: SourceNameOptionsCommand(output=10, source_selector=3, options=000001, hidden_name=None, name='Analog 1')
# <-- 290A00000001416E616C6F672032: SourceNameOptionsCommand(output=10, source_selector=0, options=000001, hidden_name=None, name='Analog 2')
# <-- 290A01000001416E616C6F672033: SourceNameOptionsCommand(output=10, source_selector=1, options=000001, hidden_name=None, name='Analog 3')
# <-- 290A02000001416E616C6F672034: SourceNameOptionsCommand(output=10, source_selector=2, options=000001, hidden_name=None, name='Analog 4')
# <-- 290A04000001436F617869616C2031: SourceNameOptionsCommand(output=10, source_selector=4, options=000001, hidden_name=None, name='Coaxial 1')
# ...
# <-- 0D05A0C8: MaximumVolumeCommand(output=5, max_volume=1.0, detail=(200,))
# <-- 0D06A0C8: MaximumVolumeCommand(output=6, max_volume=1.0, detail=(200,))
# <-- 0D07A0C8: MaximumVolumeCommand(output=7, max_volume=1.0, detail=(200,))
# <-- 0D08A0C8: MaximumVolumeCommand(output=8, max_volume=1.0, detail=(200,))
# <-- 1C094772696C6C: ZoneNameCommand(output=9, name='Grill')
# <-- 1C0A506174696F2057657374: ZoneNameCommand(output=10, name='Patio West')
# <-- 1C0B506174696F2045617374: ZoneNameCommand(output=11, name='Patio East')
# <-- 1C0C506F6F6C: ZoneNameCommand(output=12, name='Pool')
# <-- 1C0D: ZoneNameCommand(output=13, name='')
# <-- 1C0E: ZoneNameCommand(output=14, name='')
# <-- 1C0F: ZoneNameCommand(output=15, name='')
# <-- 1C10: ZoneNameCommand(output=16, name='')
# <-- 1C014B69746368656E: ZoneNameCommand(output=1, name='Kitchen')
# <-- 1C0244696E696E67: ZoneNameCommand(output=2, name='Dining')
# <-- 1C034C6976696E67: ZoneNameCommand(output=3, name='Living')
# <-- 1C044D6173746572: ZoneNameCommand(output=4, name='Master')
# <-- 1C0542617468726F6F6D: ZoneNameCommand(output=5, name='Bathroom')
# <-- 1C06466F796572: ZoneNameCommand(output=6, name='Foyer')
# <-- 1C0753697474696E67: ZoneNameCommand(output=7, name='Sitting')
# <-- 1C08506173737468726F756768: ZoneNameCommand(output=8, name='Passthrough')
# <-- 4FFF0000194E67A9F8BEF6A4653D0FBEE12977065731: DistributedSourceDefinitionCommand(output=255, slot_id=0, backing_device_guid=UUID('674e1900-f8a9-f6be-a465-3d0fbee12977'), source_index=6, name='W1')
# <-- 4FFF016C126887DF88BD41ABBD079C4E74369400506C617965725F4140414345313446303036303132: DistributedSourceDefinitionCommand(output=255, slot_id=1, backing_device_guid=UUID('8768126c-88df-41bd-abbd-079c4e743694'), source_index=0, name='Player_A@ACE14F006012')
# <-- 4FFF0200194E67A9F8BEF6A4653D0FBEE12977075732: DistributedSourceDefinitionCommand(output=255, slot_id=2, backing_device_guid=UUID('674e1900-f8a9-f6be-a465-3d0fbee12977'), source_index=7, name='W2')
# <-- 4FFF038768126C88DF41BDABBD079C4E743694095733: DistributedSourceDefinitionCommand(output=255, slot_id=3, backing_device_guid=UUID('6c126887-df88-bd41-abbd-079c4e743694'), source_index=9, name='W3')
# <-- 4FFF048768126C88DF41BDABBD079C4E7436940A5734: DistributedSourceDefinitionCommand(output=255, slot_id=4, backing_device_guid=UUID('6c126887-df88-bd41-abbd-079c4e743694'), source_index=10, name='W4')
# <-- 4FFF058768126C88DF41BDABBD079C4E74369403506173737468726F75676820496E: DistributedSourceDefinitionCommand(output=255, slot_id=5, backing_device_guid=UUID('6c126887-df88-bd41-abbd-079c4e743694'), source_index=3, name='Passthrough In')
# <-- 4FFF066C126887DF88BD41ABBD079C4E74369402506C617965725F4340414345313446303036303132: DistributedSourceDefinitionCommand(output=255, slot_id=6, backing_device_guid=UUID('8768126c-88df-41bd-abbd-079c4e743694'), source_index=2, name='Player_C@ACE14F006012')
# <-- 4FFF076C126887DF88BD41ABBD079C4E74369401506C617965725F4240414345313446303036303132: DistributedSourceDefinitionCommand(output=255, slot_id=7, backing_device_guid=UUID('8768126c-88df-41bd-abbd-079c4e743694'), source_index=1, name='Player_B@ACE14F006012')
# <-- 4FFF0800: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=8)
# <-- 4FFF0900: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=9)
# <-- 4FFF0A00: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=10)
# <-- 4FFF0B00: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=11)
# <-- 4FFF0C00: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=12)
# <-- 4FFF0D00: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=13)
# <-- 4FFF0E00: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=14)
# <-- 4FFF0F00: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=15)
# <-- 4FFF1000: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=16)
# <-- 4FFF1100: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=17)
# <-- 4FFF1200: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=18)
# <-- 4FFF1300: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=19)
# <-- 4FFF1400: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=20)
# <-- 4FFF1500: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=21)
# <-- 4FFF1600: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=22)
# <-- 4FFF1700: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=23)
# <-- 4FFF1800: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=24)
# <-- 4FFF1900: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=25)
# <-- 4FFF1A00: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=26)
# <-- 4FFF1B00: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=27)
# <-- 4FFF1C00: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=28)
# <-- 4FFF1D00: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=29)
# <-- 4FFF1E00: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=30)
# <-- 4FFF1F00: DistributedSourceDefinitionUnusedCommand(output=255, slot_id=31)
# <-- B9FF000000D40603001D230A0100C8ACE14F0055B41907150002: RequestExtendedDeviceInformationCommandResponse(device_id=00D4, prefix=0000, model_info=0603001D230A0100C8, mac=ACE14F0055B4, detail=1907150002)
# --> 01ff01: StandbyPowerCommand(output=255, is_on=On)
# --> 01ff01: StandbyPowerCommand(output=255, is_on=On)
# <-- 040932: VolumeCommand(output=9, volume=0.3125, detail=())
# <-- 04010000: VolumeCommand(output=1, volume=0.0, detail=(0,))
# <-- 04020000: VolumeCommand(output=2, volume=0.0, detail=(0,))
# <-- 04030000: VolumeCommand(output=3, volume=0.0, detail=(0,))
# <-- 04040000: VolumeCommand(output=4, volume=0.0, detail=(0,))
# <-- 04050000: VolumeCommand(output=5, volume=0.0, detail=(0,))
# <-- 04060000: VolumeCommand(output=6, volume=0.0, detail=(0,))
# <-- 04070000: VolumeCommand(output=7, volume=0.0, detail=(0,))
# <-- 04080000: VolumeCommand(output=8, volume=0.0, detail=(0,))
# <-- 040932: VolumeCommand(output=9, volume=0.3125, detail=())
# <-- 040A32: VolumeCommand(output=10, volume=0.3125, detail=())
# <-- 040A32: VolumeCommand(output=10, volume=0.3125, detail=())
# <-- 040B32: VolumeCommand(output=11, volume=0.3125, detail=())
# <-- 040B32: VolumeCommand(output=11, volume=0.3125, detail=())
# <-- 040C32: VolumeCommand(output=12, volume=0.3125, detail=())
# <-- 040C32: VolumeCommand(output=12, volume=0.3125, detail=())
# <-- 040D32: VolumeCommand(output=13, volume=0.3125, detail=())
# <-- 040D32: VolumeCommand(output=13, volume=0.3125, detail=())
# <-- 040E32: VolumeCommand(output=14, volume=0.3125, detail=())
# <-- 040E32: VolumeCommand(output=14, volume=0.3125, detail=())
# <-- 14FF06: RequestDeviceInformationCommand(output=255, options=6)
# <-- 040F32: VolumeCommand(output=15, volume=0.3125, detail=())
# <-- 040F32: VolumeCommand(output=15, volume=0.3125, detail=())
# <-- 041032: VolumeCommand(output=16, volume=0.3125, detail=())
# <-- 041032: VolumeCommand(output=16, volume=0.3125, detail=())
# <-- 01FF01: StandbyPowerCommand(output=255, is_on=On)
# <-- 04010000: VolumeCommand(output=1, volume=0.0, detail=(0,))
# <-- 04020000: VolumeCommand(output=2, volume=0.0, detail=(0,))
# <-- 04030000: VolumeCommand(output=3, volume=0.0, detail=(0,))
# <-- 04040000: VolumeCommand(output=4, volume=0.0, detail=(0,))
# <-- 04050000: VolumeCommand(output=5, volume=0.0, detail=(0,))
# <-- 04060000: VolumeCommand(output=6, volume=0.0, detail=(0,))
# <-- 04070000: VolumeCommand(output=7, volume=0.0, detail=(0,))
# <-- 04080000: VolumeCommand(output=8, volume=0.0, detail=(0,))
# <-- 94FF0006B000D40102030405060708: RequestDeviceInformationCommandResponse(device_id=00D4, firmware=6, model_id=B0, zones=(1, 2, 3, 4, 5, 6, 7, 8))
# <-- 01FF01: StandbyPowerCommand(output=255, is_on=On)
# <-- 94FF0008E96012090A0B0C0D0E0F10: RequestDeviceInformationCommandResponse(device_id=6012, firmware=8, model_id=E9, zones=(9, 10, 11, 12, 13, 14, 15, 16))
# <-- B9FF000000D40603001D230A0100C8ACE14F0055B41907150002: RequestExtendedDeviceInformationCommandResponse(device_id=00D4, prefix=0000, model_info=0603001D230A0100C8, mac=ACE14F0055B4, detail=1907150002)
# <-- 39FF6012: RequestExtendedDeviceInformationCommand(output=255, device_id=6012)
# <-- 39FF6012: RequestExtendedDeviceInformationCommand(output=255, device_id=6012)
# <-- B9FF4F0060120803001C1C0A0100C9ACE14F00601211040F00AF: RequestExtendedDeviceInformationCommandResponse(device_id=6012, prefix=4F00, model_info=0803001C1C0A0100C9, mac=ACE14F006012, detail=11040F00AF)
# <-- B9FF4F0060120803001C1C0A0100C9ACE14F00601211040F00AF: RequestExtendedDeviceInformationCommandResponse(device_id=6012, prefix=4F00, model_info=0803001C1C0A0100C9, mac=ACE14F006012, detail=11040F00AF)
# <-- 4DFF6012: KeypadPortOccupancyCommand(output=255, device_id=6012)
# <-- B9FF4F0060120803001C1C0A0100C9ACE14F00601211040F00AF: RequestExtendedDeviceInformationCommandResponse(device_id=6012, prefix=4F00, model_info=0803001C1C0A0100C9, mac=ACE14F006012, detail=11040F00AF)
# <-- B9FF4F0060120803001C1C0A0100C9ACE14F00601211040F00AF: RequestExtendedDeviceInformationCommandResponse(device_id=6012, prefix=4F00, model_info=0803001C1C0A0100C9, mac=ACE14F006012, detail=11040F00AF)
# --> 04ff50: VolumeCommand(output=255, volume=0.5, detail=())
# --> 04ff50: VolumeCommand(output=255, volume=0.5, detail=())
# <-- 020901: MuteCommand(output=9, is_muted=Off)
# <-- 020901: MuteCommand(output=9, is_muted=Off)
# <-- 020A01: MuteCommand(output=10, is_muted=Off)
# <-- 020A01: MuteCommand(output=10, is_muted=Off)
# <-- 020B01: MuteCommand(output=11, is_muted=Off)
# <-- 020B01: MuteCommand(output=11, is_muted=Off)
# <-- 020C01: MuteCommand(output=12, is_muted=Off)
# <-- 020C01: MuteCommand(output=12, is_muted=Off)
# <-- 020D01: MuteCommand(output=13, is_muted=Off)
# <-- 020D01: MuteCommand(output=13, is_muted=Off)
# <-- 020E01: MuteCommand(output=14, is_muted=Off)
# <-- 020E01: MuteCommand(output=14, is_muted=Off)
# <-- 020F01: MuteCommand(output=15, is_muted=Off)
# <-- 020F01: MuteCommand(output=15, is_muted=Off)
# <-- 021001: MuteCommand(output=16, is_muted=Off)
# <-- 021001: MuteCommand(output=16, is_muted=Off)
# <-- 04FF50: VolumeCommand(output=255, volume=0.5, detail=())
# <-- 04FF50: VolumeCommand(output=255, volume=0.5, detail=())
# <-- CDFF00D400: KeypadPortOccupancyCommandResponse(output=255, device_id=00D4, occupancy=0)
# --> 03ff20: SourceSelectionCommand(output=255, source=32, detail=())
# --> 03ff20: SourceSelectionCommand(output=255, source=32, detail=())
# <-- 03018220: SourceSelectionCommand(output=1, source=130, detail=(32,))
# <-- 03028220: SourceSelectionCommand(output=2, source=130, detail=(32,))
# <-- 03038220: SourceSelectionCommand(output=3, source=130, detail=(32,))
# <-- 03048220: SourceSelectionCommand(output=4, source=130, detail=(32,))
# <-- 03058220: SourceSelectionCommand(output=5, source=130, detail=(32,))
# <-- 03068220: SourceSelectionCommand(output=6, source=130, detail=(32,))
# <-- 03078220: SourceSelectionCommand(output=7, source=130, detail=(32,))
# <-- 03088220: SourceSelectionCommand(output=8, source=130, detail=(32,))
# <-- 03018220: SourceSelectionCommand(output=1, source=130, detail=(32,))
# <-- 03028220: SourceSelectionCommand(output=2, source=130, detail=(32,))
# <-- 03038220: SourceSelectionCommand(output=3, source=130, detail=(32,))
# <-- 03048220: SourceSelectionCommand(output=4, source=130, detail=(32,))
# <-- 03058220: SourceSelectionCommand(output=5, source=130, detail=(32,))
# <-- 03068220: SourceSelectionCommand(output=6, source=130, detail=(32,))
# <-- 03078220: SourceSelectionCommand(output=7, source=130, detail=(32,))
# <-- 03088220: SourceSelectionCommand(output=8, source=130, detail=(32,))
# <-- 03FF20: SourceSelectionCommand(output=255, source=32, detail=())
# <-- 03018220: SourceSelectionCommand(output=1, source=130, detail=(32,))
# <-- 03028220: SourceSelectionCommand(output=2, source=130, detail=(32,))
# <-- 03038220: SourceSelectionCommand(output=3, source=130, detail=(32,))
# <-- 03048220: SourceSelectionCommand(output=4, source=130, detail=(32,))
# <-- 03058220: SourceSelectionCommand(output=5, source=130, detail=(32,))
# <-- 03068220: SourceSelectionCommand(output=6, source=130, detail=(32,))
# <-- 03078220: SourceSelectionCommand(output=7, source=130, detail=(32,))
# <-- 03088220: SourceSelectionCommand(output=8, source=130, detail=(32,))
# <-- 03018220: SourceSelectionCommand(output=1, source=130, detail=(32,))
# <-- 03028220: SourceSelectionCommand(output=2, source=130, detail=(32,))
# <-- 03038220: SourceSelectionCommand(output=3, source=130, detail=(32,))
# <-- 03048220: SourceSelectionCommand(output=4, source=130, detail=(32,))
# <-- 03058220: SourceSelectionCommand(output=5, source=130, detail=(32,))
# <-- 03068220: SourceSelectionCommand(output=6, source=130, detail=(32,))
# <-- 03078220: SourceSelectionCommand(output=7, source=130, detail=(32,))
# <-- 03088220: SourceSelectionCommand(output=8, source=130, detail=(32,))
# <-- 32FF2000: SourceGainCommand(output=255, source_selector=32, gains=(0.0,))
# <-- 32FF2000: SourceGainCommand(output=255, source_selector=32, gains=(0.0,))
# --> 01ff: StandbyPowerCommand(output=255, is_on=None)
# --> 01ff: StandbyPowerCommand(output=255, is_on=None)
# --> 02ff: MuteCommand(output=255, is_muted=None)
# --> 02ff: MuteCommand(output=255, is_muted=None)
# --> 03ff: SourceSelectionCommand(output=255, source=None, detail=())
# --> 03ff: SourceSelectionCommand(output=255, source=None, detail=())
# --> 04ff: VolumeCommand(output=255, volume=None, detail=())
# --> 04ff: VolumeCommand(output=255, volume=None, detail=())
# --> 0dff: MaximumVolumeCommand(output=255, max_volume=None, detail=())
# --> 0dff: MaximumVolumeCommand(output=255, max_volume=None, detail=())
# <-- 010901: StandbyPowerCommand(output=9, is_on=On)
# <-- 010A01: StandbyPowerCommand(output=10, is_on=On)
# <-- 010B01: StandbyPowerCommand(output=11, is_on=On)
# <-- 010C01: StandbyPowerCommand(output=12, is_on=On)
# <-- 010D01: StandbyPowerCommand(output=13, is_on=On)
# <-- 010E01: StandbyPowerCommand(output=14, is_on=On)
# <-- 010F01: StandbyPowerCommand(output=15, is_on=On)
# <-- 011001: StandbyPowerCommand(output=16, is_on=On)
# <-- 020901: MuteCommand(output=9, is_muted=Off)
# <-- 020A01: MuteCommand(output=10, is_muted=Off)
# <-- 020B01: MuteCommand(output=11, is_muted=Off)
# <-- 020C01: MuteCommand(output=12, is_muted=Off)
# <-- 020D01: MuteCommand(output=13, is_muted=Off)
# <-- 020E01: MuteCommand(output=14, is_muted=Off)
# <-- 020F01: MuteCommand(output=15, is_muted=Off)
# <-- 021001: MuteCommand(output=16, is_muted=Off)
# <-- 0309A0: SourceSelectionCommand(output=9, source=160, detail=())
# <-- 030AA0: SourceSelectionCommand(output=10, source=160, detail=())
# <-- 030BA0: SourceSelectionCommand(output=11, source=160, detail=())
# <-- 030CA0: SourceSelectionCommand(output=12, source=160, detail=())
# <-- 030DA0: SourceSelectionCommand(output=13, source=160, detail=())
# <-- 030EA0: SourceSelectionCommand(output=14, source=160, detail=())
# <-- 030FA0: SourceSelectionCommand(output=15, source=160, detail=())
# <-- 0310A0: SourceSelectionCommand(output=16, source=160, detail=())
# <-- 040950: VolumeCommand(output=9, volume=0.5, detail=())
# <-- 040A50: VolumeCommand(output=10, volume=0.5, detail=())
# <-- 040B50: VolumeCommand(output=11, volume=0.5, detail=())
# <-- 040C50: VolumeCommand(output=12, volume=0.5, detail=())
# <-- 040D50: VolumeCommand(output=13, volume=0.5, detail=())
# <-- 040E50: VolumeCommand(output=14, volume=0.5, detail=())
# <-- 040F50: VolumeCommand(output=15, volume=0.5, detail=())
# <-- 041050: VolumeCommand(output=16, volume=0.5, detail=())
# <-- 0D09A0000000: MaximumVolumeCommand(output=9, max_volume=1.0, detail=(0, 0, 0))
# <-- 0D0AA0000000: MaximumVolumeCommand(output=10, max_volume=1.0, detail=(0, 0, 0))
# <-- 0D0BA0000000: MaximumVolumeCommand(output=11, max_volume=1.0, detail=(0, 0, 0))
# <-- 0D0CA0000000: MaximumVolumeCommand(output=12, max_volume=1.0, detail=(0, 0, 0))
# <-- 0D0DA0000000: MaximumVolumeCommand(output=13, max_volume=1.0, detail=(0, 0, 0))
# <-- 0D0EA0000000: MaximumVolumeCommand(output=14, max_volume=1.0, detail=(0, 0, 0))
# <-- 0D0FA0000000: MaximumVolumeCommand(output=15, max_volume=1.0, detail=(0, 0, 0))
# <-- 0D10A0000000: MaximumVolumeCommand(output=16, max_volume=1.0, detail=(0, 0, 0))

# %%
all_outputs = system.all_outputs()
w1 = system.input_by_name("W1")

print(f"W1 selector: 0x{w1.selector:02X}")
# Out:
# W1 selector: 0x20

# %%
# Enable everything.
all_outputs.enable()

# %%
# Set all outputs to the same volume.
all_outputs.set_volume(VOLUME)

# %%
# Set all outputs to the input named W1.
all_outputs.set_input(w1)

# %%
# Mute everything.
all_outputs.mute()

# %%
system.refresh_outputs()
await asyncio.sleep(2)
system.dump()
system.shutdown()
# Out:
# Devices (2):
#   version=8 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 17, 917190, tzinfo=datetime.timezone.utc) id=00D4 host='10.1.0.200' firmware=6 model_id=B0 input_count=8 output_count=8 outputs=(1, 2, 3, 4, 5, 6, 7, 8) mac=ACE14F0055B4 guid=UUID('674e1900-f8a9-f6be-a465-3d0fbee12977')
#   version=8 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 206740, tzinfo=datetime.timezone.utc) id=6012 host='10.1.0.201' firmware=8 model_id=E9 input_count=19 output_count=8 outputs=(9, 10, 11, 12, 13, 14, 15, 16) mac=ACE14F006012 guid=UUID('6c126887-df88-bd41-abbd-079c4e743694')
# Inputs (35):
#   00D4:0x20: version=1 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 308716, tzinfo=datetime.timezone.utc) device_id=00D4 selector=32 assigned_name='W1' hidden_name=None hardware_name=None
#   00D4:0x21: version=1 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 308829, tzinfo=datetime.timezone.utc) device_id=00D4 selector=33 assigned_name='Player_A@ACE14F006012' hidden_name=None hardware_name=None
#   00D4:0x22: version=1 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 308943, tzinfo=datetime.timezone.utc) device_id=00D4 selector=34 assigned_name='W2' hidden_name=None hardware_name=None
#   00D4:0x23: version=1 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 414531, tzinfo=datetime.timezone.utc) device_id=00D4 selector=35 assigned_name='W3' hidden_name=None hardware_name=None
#   00D4:0x24: version=1 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 414651, tzinfo=datetime.timezone.utc) device_id=00D4 selector=36 assigned_name='W4' hidden_name=None hardware_name=None
#   00D4:0x25: version=1 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 414770, tzinfo=datetime.timezone.utc) device_id=00D4 selector=37 assigned_name='Passthrough In' hidden_name=None hardware_name=None
#   00D4:0x26: version=1 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 414878, tzinfo=datetime.timezone.utc) device_id=00D4 selector=38 assigned_name='Player_C@ACE14F006012' hidden_name=None hardware_name=None
#   00D4:0x27: version=1 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 414986, tzinfo=datetime.timezone.utc) device_id=00D4 selector=39 assigned_name='Player_B@ACE14F006012' hidden_name=None hardware_name=None
#   00D4:1: version=2 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 214956, tzinfo=datetime.timezone.utc) device_id=00D4 selector=5 assigned_name='A1' hidden_name=None hardware_name='A1'
#   00D4:2: version=2 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 214986, tzinfo=datetime.timezone.utc) device_id=00D4 selector=6 assigned_name='A2' hidden_name=None hardware_name='A2'
#   00D4:3: version=2 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 307944, tzinfo=datetime.timezone.utc) device_id=00D4 selector=7 assigned_name='A3' hidden_name=None hardware_name='A3'
#   00D4:4: version=2 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 307983, tzinfo=datetime.timezone.utc) device_id=00D4 selector=3 assigned_name='A4' hidden_name=None hardware_name='A4'
#   00D4:5: version=2 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 308298, tzinfo=datetime.timezone.utc) device_id=00D4 selector=0 assigned_name='COAX1' hidden_name=None hardware_name='COAX1'
#   00D4:6: version=2 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 308342, tzinfo=datetime.timezone.utc) device_id=00D4 selector=1 assigned_name='COAX2' hidden_name=None hardware_name='COAX2'
#   00D4:7: version=2 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 308498, tzinfo=datetime.timezone.utc) device_id=00D4 selector=2 assigned_name='W1' hidden_name=None hardware_name='OPT1'
#   00D4:8: version=2 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 308540, tzinfo=datetime.timezone.utc) device_id=00D4 selector=4 assigned_name='W2' hidden_name=None hardware_name='OPT2'
#   6012:0x50: version=3 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 657287, tzinfo=datetime.timezone.utc) device_id=6012 selector=80 assigned_name='Casting_6' hidden_name='Casting_6@ACE14F006012' hardware_name='Casting_6'
#   6012:0x51: version=3 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 657308, tzinfo=datetime.timezone.utc) device_id=6012 selector=81 assigned_name='Casting_7' hidden_name='Casting_7@ACE14F006012' hardware_name='Casting_7'
#   6012:0x52: version=3 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 657329, tzinfo=datetime.timezone.utc) device_id=6012 selector=82 assigned_name='Casting_8' hidden_name='Casting_8@ACE14F006012' hardware_name='Casting_8'
#   6012:1: version=3 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 632450, tzinfo=datetime.timezone.utc) device_id=6012 selector=5 assigned_name='Player_A' hidden_name='Player_A@ACE14F006012' hardware_name='Player_A'
#   6012:10: version=2 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 642250, tzinfo=datetime.timezone.utc) device_id=6012 selector=9 assigned_name='W3' hidden_name=None hardware_name='Optical 1'
#   6012:11: version=2 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 642264, tzinfo=datetime.timezone.utc) device_id=6012 selector=10 assigned_name='W4' hidden_name=None hardware_name='Optical 2'
#   6012:12: version=3 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 642289, tzinfo=datetime.timezone.utc) device_id=6012 selector=11 assigned_name='Casting_1' hidden_name='Casting_1@ACE14F006012' hardware_name='Casting_1'
#   6012:13: version=3 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 643539, tzinfo=datetime.timezone.utc) device_id=6012 selector=12 assigned_name='Casting_2' hidden_name='Casting_2@ACE14F006012' hardware_name='Casting_2'
#   6012:14: version=3 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 657217, tzinfo=datetime.timezone.utc) device_id=6012 selector=13 assigned_name='Casting_3' hidden_name='Casting_3@ACE14F006012' hardware_name='Casting_3'
#   6012:15: version=3 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 657243, tzinfo=datetime.timezone.utc) device_id=6012 selector=14 assigned_name='Casting_4' hidden_name='Casting_4@ACE14F006012' hardware_name='Casting_4'
#   6012:16: version=3 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 657266, tzinfo=datetime.timezone.utc) device_id=6012 selector=15 assigned_name='Casting_5' hidden_name='Casting_5@ACE14F006012' hardware_name='Casting_5'
#   6012:2: version=3 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 635826, tzinfo=datetime.timezone.utc) device_id=6012 selector=6 assigned_name='Player_B' hidden_name='Player_B@ACE14F006012' hardware_name='Player_B'
#   6012:3: version=3 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 635853, tzinfo=datetime.timezone.utc) device_id=6012 selector=7 assigned_name='Player_C' hidden_name='Player_C@ACE14F006012' hardware_name='Player_C'
#   6012:4: version=2 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 642147, tzinfo=datetime.timezone.utc) device_id=6012 selector=3 assigned_name='Analog 1' hidden_name=None hardware_name='Analog 1'
#   6012:5: version=2 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 642173, tzinfo=datetime.timezone.utc) device_id=6012 selector=0 assigned_name='Analog 2' hidden_name=None hardware_name='Analog 2'
#   6012:6: version=2 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 642191, tzinfo=datetime.timezone.utc) device_id=6012 selector=1 assigned_name='Analog 3' hidden_name=None hardware_name='Analog 3'
#   6012:7: version=2 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 642207, tzinfo=datetime.timezone.utc) device_id=6012 selector=2 assigned_name='Analog 4' hidden_name=None hardware_name='Analog 4'
#   6012:8: version=2 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 642222, tzinfo=datetime.timezone.utc) device_id=6012 selector=4 assigned_name='Coaxial 1' hidden_name=None hardware_name='Coaxial 1'
#   6012:9: version=2 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 642236, tzinfo=datetime.timezone.utc) device_id=6012 selector=8 assigned_name='Coaxial 2' hidden_name=None hardware_name='Coaxial 2'
# Outputs (16):
#   version=9 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 50, 801881, tzinfo=datetime.timezone.utc) id=1 name='Kitchen' on=True muted=False source=2 volume=0.5 max_volume=1.0
#   version=9 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 50, 802332, tzinfo=datetime.timezone.utc) id=2 name='Dining' on=True muted=False source=2 volume=0.5 max_volume=1.0
#   version=9 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 50, 803179, tzinfo=datetime.timezone.utc) id=3 name='Living' on=True muted=False source=2 volume=0.5 max_volume=1.0
#   version=9 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 50, 803913, tzinfo=datetime.timezone.utc) id=4 name='Master' on=True muted=False source=2 volume=0.5 max_volume=1.0
#   version=9 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 50, 804323, tzinfo=datetime.timezone.utc) id=5 name='Bathroom' on=True muted=False source=2 volume=0.5 max_volume=1.0
#   version=9 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 50, 805151, tzinfo=datetime.timezone.utc) id=6 name='Foyer' on=True muted=False source=2 volume=0.5 max_volume=1.0
#   version=9 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 50, 805829, tzinfo=datetime.timezone.utc) id=7 name='Sitting' on=True muted=False source=2 volume=0.5 max_volume=1.0
#   version=9 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 50, 806308, tzinfo=datetime.timezone.utc) id=8 name='Passthrough' on=True muted=False source=2 volume=0.5 max_volume=1.0
#   version=11 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 51, 244465, tzinfo=datetime.timezone.utc) id=9 name='Grill' on=True muted=False source=32 volume=0.5 max_volume=1.0
#   version=11 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 51, 244493, tzinfo=datetime.timezone.utc) id=10 name='Patio West' on=True muted=False source=32 volume=0.5 max_volume=1.0
#   version=11 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 51, 244504, tzinfo=datetime.timezone.utc) id=11 name='Patio East' on=True muted=False source=32 volume=0.5 max_volume=1.0
#   version=11 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 51, 244515, tzinfo=datetime.timezone.utc) id=12 name='Pool' on=True muted=False source=32 volume=0.5 max_volume=1.0
#   version=11 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 51, 244525, tzinfo=datetime.timezone.utc) id=13 name='' on=True muted=False source=32 volume=0.5 max_volume=1.0
#   version=11 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 51, 244535, tzinfo=datetime.timezone.utc) id=14 name='' on=True muted=False source=32 volume=0.5 max_volume=1.0
#   version=11 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 51, 244545, tzinfo=datetime.timezone.utc) id=15 name='' on=True muted=False source=32 volume=0.5 max_volume=1.0
#   version=11 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 51, 244554, tzinfo=datetime.timezone.utc) id=16 name='' on=True muted=False source=32 volume=0.5 max_volume=1.0
# Remote Inputs (32):
#   version=4 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 415500, tzinfo=datetime.timezone.utc) id=0 present=True device_guid=UUID('674e1900-f8a9-f6be-a465-3d0fbee12977') source_index=6 name='W1'
#   version=4 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 415542, tzinfo=datetime.timezone.utc) id=1 present=True device_guid=UUID('8768126c-88df-41bd-abbd-079c4e743694') source_index=0 name='Player_A@ACE14F006012'
#   version=4 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 415581, tzinfo=datetime.timezone.utc) id=2 present=True device_guid=UUID('674e1900-f8a9-f6be-a465-3d0fbee12977') source_index=7 name='W2'
#   version=4 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 415620, tzinfo=datetime.timezone.utc) id=3 present=True device_guid=UUID('6c126887-df88-bd41-abbd-079c4e743694') source_index=9 name='W3'
#   version=4 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 415658, tzinfo=datetime.timezone.utc) id=4 present=True device_guid=UUID('6c126887-df88-bd41-abbd-079c4e743694') source_index=10 name='W4'
#   version=4 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 415703, tzinfo=datetime.timezone.utc) id=5 present=True device_guid=UUID('6c126887-df88-bd41-abbd-079c4e743694') source_index=3 name='Passthrough In'
#   version=4 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 415740, tzinfo=datetime.timezone.utc) id=6 present=True device_guid=UUID('8768126c-88df-41bd-abbd-079c4e743694') source_index=2 name='Player_C@ACE14F006012'
#   version=4 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 415835, tzinfo=datetime.timezone.utc) id=7 present=True device_guid=UUID('8768126c-88df-41bd-abbd-079c4e743694') source_index=1 name='Player_B@ACE14F006012'
#   version=1 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 415847, tzinfo=datetime.timezone.utc) id=8 present=False device_guid=None source_index=None name=None
#   version=1 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 415861, tzinfo=datetime.timezone.utc) id=9 present=False device_guid=None source_index=None name=None
#   version=1 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 415874, tzinfo=datetime.timezone.utc) id=10 present=False device_guid=None source_index=None name=None
#   version=1 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 415887, tzinfo=datetime.timezone.utc) id=11 present=False device_guid=None source_index=None name=None
#   version=1 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 415900, tzinfo=datetime.timezone.utc) id=12 present=False device_guid=None source_index=None name=None
#   version=1 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 415913, tzinfo=datetime.timezone.utc) id=13 present=False device_guid=None source_index=None name=None
#   version=1 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 415925, tzinfo=datetime.timezone.utc) id=14 present=False device_guid=None source_index=None name=None
#   version=1 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 415938, tzinfo=datetime.timezone.utc) id=15 present=False device_guid=None source_index=None name=None
#   version=1 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 415951, tzinfo=datetime.timezone.utc) id=16 present=False device_guid=None source_index=None name=None
#   version=1 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 415963, tzinfo=datetime.timezone.utc) id=17 present=False device_guid=None source_index=None name=None
#   version=1 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 415976, tzinfo=datetime.timezone.utc) id=18 present=False device_guid=None source_index=None name=None
#   version=1 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 415988, tzinfo=datetime.timezone.utc) id=19 present=False device_guid=None source_index=None name=None
#   version=1 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 416000, tzinfo=datetime.timezone.utc) id=20 present=False device_guid=None source_index=None name=None
#   version=1 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 416015, tzinfo=datetime.timezone.utc) id=21 present=False device_guid=None source_index=None name=None
#   version=1 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 416028, tzinfo=datetime.timezone.utc) id=22 present=False device_guid=None source_index=None name=None
#   version=1 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 416044, tzinfo=datetime.timezone.utc) id=23 present=False device_guid=None source_index=None name=None
#   version=1 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 416059, tzinfo=datetime.timezone.utc) id=24 present=False device_guid=None source_index=None name=None
#   version=1 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 416071, tzinfo=datetime.timezone.utc) id=25 present=False device_guid=None source_index=None name=None
#   version=1 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 416084, tzinfo=datetime.timezone.utc) id=26 present=False device_guid=None source_index=None name=None
#   version=1 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 416096, tzinfo=datetime.timezone.utc) id=27 present=False device_guid=None source_index=None name=None
#   version=1 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 416108, tzinfo=datetime.timezone.utc) id=28 present=False device_guid=None source_index=None name=None
#   version=1 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 416121, tzinfo=datetime.timezone.utc) id=29 present=False device_guid=None source_index=None name=None
#   version=1 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 416133, tzinfo=datetime.timezone.utc) id=30 present=False device_guid=None source_index=None name=None
#   version=1 updated_at=datetime.datetime(2026, 6, 1, 19, 44, 18, 416145, tzinfo=datetime.timezone.utc) id=31 present=False device_guid=None source_index=None name=None
